# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoyo-Ou/FJCU/blob/main/5_15_In_class_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

nltk.download("popular")
nltk.download("all-corpora")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
import nltk
from nltk.book import *

# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
text1
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# <Text: Moby Dick by Herman Melville 1851>

# %%
# 搜尋字詞功能
import nltk
from nltk.book import *

print(text7.count("money"))

# text3.concordance("lived", lines = 50)  #max = 50

print(text9.concordance("Science", lines = 30))  #max = 30
# Out:
# 53
# Displaying 4 of 4 matches:
# e soul when we were boys together . Science announced nonentity and art admired
# ck had no real right to the airs of science that he assumed . He had not discov
# n the fear of the airless vacuum of science . The first was the old fear that a
#  , do you ? Bull , you are a man of science . Grub in the roots of those trees
# None

# %%
import nltk
from nltk.book import *

# 近似字
text3.similar("you")

print ("----------我是分隔線-------")

text5.similar("love")

#list
context = ["love","lord", "money"]

text3.common_contexts(context)
# Out:
# thee them him me us her pharaoh joseph bread abram haran abraham isaac
# god good cattle th men noah wine
# ----------我是分隔線-------
# know got hate am did like want see join pm had give part well do lol
# hope take have make
# No common contexts were found

# %%
import nltk
from nltk.book import *

# 相異字詞
setText = set(text4)
print(setText)

# 相異字詞排序
tempText = sorted(setText)
print(tempText)

# 定義詞彙多樣性的函數
def difference(text):
    print("相異字詞數量：", len(set(text)))
    print("總字詞數量：", len(text))
    return len(set(text)) / len(text)

# 計算 text4 的詞彙多樣性
print("text4 的詞彙多樣性：", difference(text4))

print("----------我是分隔線---------")

# 比較 text2 和 text3 的詞彙多樣性
print("text2 的詞彙多樣性：", difference(text2))
print("text3 的詞彙多樣性：", difference(text3))
# Out:
# {'regulate', 'wonted', 'impossible', 'contriving', 'descending', 'proverbial', 'Employed', 'dissenting', 'healed', 'awake', 'messages', 'born', 'causes', 'block', 'prohibit', 'manifestation', 'lightness', 'terms', 'reestablished', 'confide', 'appropriations', 'witness', 'life', 'rating', 'quite', 'deadliest', 'scorn', 'condition', 'municipal', 'conceived', 'intentions', 'portion', 'obliged', 'exchanges', 'unfaltering', 'estranged', 'amicably', 'needless', 'snow', '1868', 'constituent', 'uneducated', 'travel', 'witnessing', 'unpracticed', 'ensued', 'gold', 'usurped', 'forgiveness', 'group', 'ordained', 'entry', 'Must', 'conferring', 'hold', 'isolation', 'negotiation', 'prostrate', 'shown', 'claim', 'everything', 'slavery', 'primary', 'refused', 'considerable', 'Each', 'lines', 'inventions', 'compelling', 'attendant', 'variations', 'exhibit', 'hopes', 'Missouri', 'vouchsafed', 'fears', 'insensible', 'keen', 'tempest', 'pervades', 'culpable', 'shades', 'south', 'missions', 'Mischievous'
# ...

# %%
import nltk
from nltk.book import *

# 詞彙分佈圖的關鍵詞
contexts = ["God", "man", "earth", "heaven", "light", "day", "woman"]

# 畫出 text3（創世記）的詞彙分佈圖
text3.dispersion_plot(contexts)

# %%
import nltk
from nltk.corpus import reuters

# 讀取 "livestock" 分類裡的文字
livestock_text = reuters.words(categories="livestock")

# 製作詞頻分布表（全轉小寫）
fdist = nltk.FreqDist(w.lower() for w in livestock_text)

# 要觀察的助動詞列表
modals = ['can', 'could', 'may', 'might', 'must', 'will', 'might', 'shall']

# 逐一印出每個助動詞的次數
for m in modals:
  print(m + ":", fdist[m])

print("----------我是練習題答案--------")

# 練習：print出 will 字詞的個數
print("will:", fdist["will"])
# Out:
# can: 10
# could: 16
# may: 23
# might: 4
# must: 5
# will: 103
# might: 4
# shall: 0
# ----------我是練習題答案--------
# will: 103
